# %%
# !pip install fredapi
# !pip install yfinance
# !pip install pandas-datareader
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 96.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for peewee: filename=peewee-3.17.6-py3-none-any.whl size=138891 sha256=59774cf5d447268ec84db7cff2de01395c11a6851dd64dafa1bc390365adacd7
#   Stored in directory: /root/.cache/pip/wheels/3e/23/b4/7729b2d48a34ee9d95c11f7f8dfd4ff0571a056e2691118b34
# Successfully built peewee
# ...
#   Attempting uninstall: requests
# ...

# %%
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
from fredapi import Fred
import matplotlib.pyplot as plt

# %%
# Your FRED API key (replace with your actual key)
fred = Fred(api_key='cbd136333ef1cd65783ab04229be84c1')

# Fetching US GDP data
gdp_data = fred.get_series('GDP', observation_start='1990-01-01')

# Fetching US Unemployment Rate data
unemployment_data = fred.get_series('UNRATE', observation_start='1990-01-01')

# Fetching US Inflation Rate data (CPI data can be used to calculate inflation rate)
inflation_data = fred.get_series('CPIAUCSL', observation_start='1990-01-01')

# Convert the data into a pandas DataFrame for easier manipulation
df = pd.DataFrame({
    'GDP': gdp_data,
    'Unemployment Rate': unemployment_data,
    'CPI': inflation_data
})

df
# Out:
#                  GDP  Unemployment Rate      CPI
# 1990-01-01  5872.701                5.4  127.500
# 1990-02-01       NaN                5.3  128.000
# 1990-03-01       NaN                5.2  128.600
# 1990-04-01  5960.028                5.4  128.900
# 1990-05-01       NaN                5.4  129.100
# ...              ...                ...      ...
# 2024-05-01       NaN                4.0  313.225
# 2024-06-01       NaN                4.1  313.049
# 2024-07-01       NaN                4.3  313.534
# 2024-08-01       NaN                4.2  314.121
# 2024-09-01       NaN                4.1      NaN
#
# [417 rows x 3 columns]

# %%
# Plot the GDP data for visualization
plt.plot(gdp_data)
plt.title('US GDP Over Time')
plt.xlabel('Date')
plt.ylabel('GDP')
plt.show()

# %%
# Correcting the code error by using the correct variable name 'inflation_data'
plt.plot(inflation_data)
plt.title('US CPI Over Time')
plt.xlabel('Date')
plt.ylabel('CONSUMER PRICE INDEX')
plt.show()

# %% [markdown]
# > generate a chart for fed funds effective rate in the use

# %%
# Fetching the Federal Funds Effective Rate data
fed_funds_rate = fred.get_series('FEDFUNDS', observation_start='1990-01-01')

# Plot the Federal Funds Effective Rate data for visualization
plt.plot(fed_funds_rate)
plt.title('Federal Funds Effective Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Effective Rate')
plt.show()

# %% [markdown]
# The chart for the Federal Funds Effective Rate over time has been generated.

# %%
# Fetching the Consumer Confidence Index (CCI) data
cci_data = fred.get_series('UMCSENT', observation_start='1990-01-01')

# Plot the Consumer Confidence Index data for visualization
plt.plot(cci_data)
plt.title('Consumer Confidence Index Over Time')
plt.xlabel('Date')
plt.ylabel('CCI')
plt.show()

# %% [markdown]
# The chart for the Consumer Confidence Index (CCI) over time has been generated.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7f042bc8-53ad-499e-90eb-30170f1d8f52' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
